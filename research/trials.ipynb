# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1kWojNt143IfnuM58qNxWJ3cQK-M1EHMK/view?usp=drivesdk"

# %%
file_id = url.split('/')[-2]
file_id
# Out:
# '1kWojNt143IfnuM58qNxWJ3cQK-M1EHMK'

# %%
prefix = 'https://drive.google.com/uc?export=download&id='
gdown.download(prefix + file_id,'kidney-ct-scan_images.zip',quiet=False)
# Out:
# Access denied with the following error:
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?export=download&id=1kWojNt143IfnuM58qNxWJ3cQK-M1EHMK
