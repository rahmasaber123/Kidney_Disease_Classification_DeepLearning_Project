# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Desktop\\Kidney_Disease_Classification_DeepLearning_Project\\research'

# %%
os.chdir("../")

# %%
from dataclasses import dataclass
from pathlib import Path
@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzipped_data_dir: Path

# %%
import sys
import os

# Add your project root (where "src" folder is)
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "src")))

# %%
os.chdir("../")

# %%
pip install python-box
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
import os

import zipfile
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    def prepare_data(self) -> Path:
        """
        Prepare the data by checking if the ZIP file exists and extracting it.
        """
        logger.info("Entered the prepare_data method of DataIngestion class")
        
        zip_path = Path(self.config.local_data_file)
        extract_to = Path(self.config.unzipped_data_dir)

        if not zip_path.exists():
            raise FileNotFoundError(f"ZIP file not found at {zip_path}. Make sure it exists!")

        logger.info(f"ZIP file found: {zip_path} ({get_size(zip_path)})")

        # Create extraction directory if it doesn't exist
        extract_to.mkdir(parents=True, exist_ok=True)

        # Extract the ZIP file
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)

        logger.info(f"Files extracted to: {extract_to}")
        return extract_to

# %%
def extract_zip_file(self):
    unzip_path = self.config.unzipped_data_dir
    os.makedirs(unzip_path, exist_ok=True)
    self.extract_zip_file(zip_file_path=self.config.local_data_file,
                          unzip_dir=unzip_path)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\HP\Desktop

# %%
import os

os.chdir("C:/Users/HP/Desktop/Kidney_Disease_Classification_DeepLearning_Project")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\HP\Desktop\Kidney_Disease_Classification_DeepLearning_Project

# %%
from cnnClassifier.config.configuration import ConfigurationManager

# %%
config = ConfigurationManager()
data_ingestion_config = config.data_ingestion_config()
# Out:
# [2025-11-04 17:32:42,754: INFO: common]: ✅ YAML file loaded successfully: config\config.yaml
# [2025-11-04 17:32:42,758: INFO: common]: ✅ YAML file loaded successfully: params.yaml
# [2025-11-04 17:32:42,761: INFO: common]: 📁 Directory created at: artifacts
# [2025-11-04 17:32:42,765: INFO: common]: 📁 Directory created at: data_ingestion

# %%
try:
    config_manager = ConfigurationManager()
    data_ingestion_config = config_manager.data_ingestion_config()
    print(data_ingestion_config)

    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_data()
    data_ingestion.extract_zip_file()
    print("Data ingestion completed successfully.")
except Exception as e:
    print(f"An error occurred during data ingestion: {e}")
# Out:
# [2025-11-04 17:36:35,815: INFO: common]: ✅ YAML file loaded successfully: config\config.yaml
# [2025-11-04 17:36:35,820: INFO: common]: ✅ YAML file loaded successfully: params.yaml
# [2025-11-04 17:36:35,824: INFO: common]: 📁 Directory created at: artifacts
# [2025-11-04 17:36:35,827: INFO: common]: 📁 Directory created at: data_ingestion
# DataIngestionConfig(root_dir=WindowsPath('data_ingestion'), source_URL='NA', local_data_file=WindowsPath('data/raw/kidney_ct_scan_images.zip'), unzipped_data_dir=WindowsPath('data/raw/kidney_ct_scan_images'))
# [2025-11-04 17:36:35,830: INFO: 1697623140]: Entered the download_data method of DataIngestion class
# [2025-11-04 17:36:35,833: INFO: 1697623140]: Downloading file from :[NA] to :[data_ingestion\NA]
# An error occurred during data ingestion: name 'gdown' is not defined

# %%
from pathlib import Path
import zipfile

zip_path = Path("data/raw/kidney-ct-scan-image.zip")
extract_to = Path("data/raw/kidney_ct_scan_images")

extract_to.mkdir(parents=True, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print(f"Files extracted to: {extract_to}")
# Out:
# Files extracted to: data\raw\kidney_ct_scan_images
